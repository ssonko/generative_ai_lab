# %% [markdown]
# Architecture
# LLM Host (MCP Client) <—— JSON-RPC ——> fastmcp Server <——> CSV Dataset
#
# We'll:
#
# Launch a server exposing two tools (summarize, query).
# Use an MCP Client to discover and call those tools.
# Simulate a host (agent) deciding which tool to call.

# %% [markdown]
# Start the MCP Server
# In a separate terminal, run:
#
# python mcp_server_fastmcp.py
# This starts an MCP-compliant server exposing summarize and query tools.

# %% [markdown]
# 1. Install dependencies

# %%
# %pip install fastmcp pandas langchain openai uvicorn --upgrade --no-cache-dir
# Out:
# Requirement already satisfied: fastmcp in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (2.14.0)
# Requirement already satisfied: pandas in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: langchain in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (1.1.3)
# Requirement already satisfied: openai in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (2.11.0)
# Requirement already satisfied: uvicorn in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (0.38.0)
# Requirement already satisfied: authlib>=1.6.5 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from fastmcp) (1.6.6)
# Requirement already satisfied: cyclopts>=4.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from fastmcp) (4.3.0)
# Requirement already satisfied: exceptiongroup>=1.2.2 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from fastmcp) (1.3.1)
# Requirement already satisfied: httpx>=0.28.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from fastmcp) (0.28.1)
# Requirement already satisfied: jsonschema-path>=0.3.4 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from fastmcp) (0.3.4)
# Requirement already satisfied: mcp>=1.23.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from fastmcp) (1.24.0)
# Requirement already satisfied: openapi-pydantic>=0.5.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from fastmcp) (0.5.1)
# Requirement already satisfied: platformdirs>=4.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from fastmcp) (4.5.0)
# Requirement already satisfied: py-key-value-aio<0.4.0,>=0.3.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (0.3.0)
# Requirement already satisfied: pydantic>=2.11.7 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pydantic[email]>=2.11.7->fastmcp) (2.12.3)
# Requirement already satisfied: pydocket>=0.15.2 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from fastmcp) (0.15.5)
# Requirement already satisfied: pyperclip>=1.9.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from fastmcp) (1.11.0)
# Requirement already satisfied: python-dotenv>=1.1.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from fastmcp) (1.2.1)
# Requirement already satisfied: rich>=13.9.4 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from fastmcp) (14.2.0)
# Requirement already satisfied: websockets>=15.0.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from fastmcp) (15.0.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.2 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langchain) (1.2.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langchain) (1.0.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from openai) (0.11.1)
# Requirement already satisfied: sniffio in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: click>=7.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from uvicorn) (8.3.1)
# Requirement already satisfied: h11>=0.8 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: idna>=2.8 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: cryptography in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from authlib>=1.6.5->fastmcp) (46.0.3)
# Requirement already satisfied: colorama in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Requirement already satisfied: attrs>=23.1.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from cyclopts>=4.0.0->fastmcp) (25.4.0)
# Requirement already satisfied: docstring-parser<4.0,>=0.15 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from cyclopts>=4.0.0->fastmcp) (0.17.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from cyclopts>=4.0.0->fastmcp) (1.3.2)
# Requirement already satisfied: certifi in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from httpx>=0.28.1->fastmcp) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from httpx>=0.28.1->fastmcp) (1.0.9)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from jsonschema-path>=0.3.4->fastmcp) (6.0.3)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from jsonschema-path>=0.3.4->fastmcp) (0.4.4)
# Requirement already satisfied: referencing<0.37.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from jsonschema-path>=0.3.4->fastmcp) (0.36.2)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from jsonschema-path>=0.3.4->fastmcp) (2.32.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (0.4.55)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (25.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (0.12.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.12)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from mcp>=1.23.1->fastmcp) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from mcp>=1.23.1->fastmcp) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from mcp>=1.23.1->fastmcp) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.23.1->fastmcp) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from mcp>=1.23.1->fastmcp) (0.0.20)
# Requirement already satisfied: pywin32>=310 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from mcp>=1.23.1->fastmcp) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from mcp>=1.23.1->fastmcp) (3.0.3)
# Requirement already satisfied: starlette>=0.27 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from mcp>=1.23.1->fastmcp) (0.50.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from mcp>=1.23.1->fastmcp) (0.4.2)
# Requirement already satisfied: py-key-value-shared==0.3.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from py-key-value-aio<0.4.0,>=0.3.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (0.3.0)
# Requirement already satisfied: beartype>=0.20.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from py-key-value-aio<0.4.0,>=0.3.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (0.22.9)
# Requirement already satisfied: diskcache>=5.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (5.6.3)
# Requirement already satisfied: pathvalidate>=3.3.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (3.3.1)
# Requirement already satisfied: keyring>=25.6.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (25.7.0)
# Requirement already satisfied: cachetools>=5.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (6.2.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pydantic>=2.11.7->pydantic[email]>=2.11.7->fastmcp) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pydantic>=2.11.7->pydantic[email]>=2.11.7->fastmcp) (2.41.4)
# Requirement already satisfied: email-validator>=2.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pydantic[email]>=2.11.7->fastmcp) (2.3.0)
# Requirement already satisfied: cloudpickle>=3.1.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pydocket>=0.15.2->fastmcp) (3.1.2)
# Requirement already satisfied: fakeredis>=2.32.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from fakeredis[lua]>=2.32.1->pydocket>=0.15.2->fastmcp) (2.32.1)
# Requirement already satisfied: opentelemetry-api>=1.33.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pydocket>=0.15.2->fastmcp) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-prometheus>=0.60b0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pydocket>=0.15.2->fastmcp) (0.60b1)
# Requirement already satisfied: opentelemetry-instrumentation>=0.60b0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pydocket>=0.15.2->fastmcp) (0.60b1)
# Requirement already satisfied: prometheus-client>=0.21.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pydocket>=0.15.2->fastmcp) (0.23.1)
# Requirement already satisfied: python-json-logger>=2.0.7 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pydocket>=0.15.2->fastmcp) (4.0.0)
# Requirement already satisfied: redis>=5 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pydocket>=0.15.2->fastmcp) (7.1.0)
# Requirement already satisfied: typer>=0.15.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from pydocket>=0.15.2->fastmcp) (0.20.0)
# Requirement already satisfied: six>=1.5 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from rich>=13.9.4->fastmcp) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from rich>=13.9.4->fastmcp) (2.19.2)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp) (2.8.0)
# Requirement already satisfied: sortedcontainers>=2 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from fakeredis>=2.32.1->fakeredis[lua]>=2.32.1->pydocket>=0.15.2->fastmcp) (2.4.0)
# Requirement already satisfied: lupa>=2.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from fakeredis[lua]>=2.32.1->pydocket>=0.15.2->fastmcp) (2.6)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.2->langchain) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.23.1->fastmcp) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.23.1->fastmcp) (0.28.0)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (0.2.3)
# Requirement already satisfied: jaraco.classes in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (3.4.0)
# Requirement already satisfied: jaraco.functools in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (4.3.0)
# Requirement already satisfied: jaraco.context in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (6.0.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain) (0.25.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp) (0.1.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from opentelemetry-api>=1.33.0->pydocket>=0.15.2->fastmcp) (8.7.0)
# Requirement already satisfied: opentelemetry-sdk~=1.39.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from opentelemetry-exporter-prometheus>=0.60b0->pydocket>=0.15.2->fastmcp) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from opentelemetry-instrumentation>=0.60b0->pydocket>=0.15.2->fastmcp) (0.60b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from opentelemetry-instrumentation>=0.60b0->pydocket>=0.15.2->fastmcp) (1.17.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from cryptography->authlib>=1.6.5->fastmcp) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path>=0.3.4->fastmcp) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path>=0.3.4->fastmcp) (2.5.0)
# Requirement already satisfied: docutils in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=4.0.0->fastmcp) (0.22.3)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from typer>=0.15.1->pydocket>=0.15.2->fastmcp) (1.5.4)
# Requirement already satisfied: pycparser in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from cffi>=2.0.0->cryptography->authlib>=1.6.5->fastmcp) (2.23)
# Requirement already satisfied: zipp>=3.20 in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.33.0->pydocket>=0.15.2->fastmcp) (3.23.0)
# Requirement already satisfied: more-itertools in c:\users\alban ssonko\training\10_2025_gen_ai_training\generative_ai_lab\.venv\lib\site-packages (from jaraco.classes->keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp) (10.8.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Connect via MCP Client
# Once the server is running, connect using the MCP client to list tools and invoke them.

# %%
from fastmcp import Client
from fastmcp.client import PythonStdioTransport
import asyncio

async def main():
    # Create a client using the PythonStdioTransport
    # Create a loop to run the client

    transport = PythonStdioTransport("mcp_server_fastmcp.py")
    # client = Client(transport)
    async with Client(transport) as client:
        tools = await client.list_tools()
        print("Tools:", [t.name for t in tools])

await main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from fastmcp import Client
#       2 from fastmcp.client import PythonStdioTransport
#       3 import asyncio
#
# File c:\Users\Alban Ssonko\Training\10_2025_GEN_AI_TRAINING\generative_ai_lab\.venv\Lib\site-packages\fastmcp\__init__.py:10
#       8 settings = Settings()
#       9 if settings.log_enabled:
# ---> 10     _configure_logging(
#      11         level=settings.log_level,
#      12         enable_rich_tracebacks=settings.enable_rich_tracebacks,
#      13     )
#      15 from fastmcp.server.server import FastMCP
#      16 from fastmcp.server.context import Context
#
# File c:\Users\Alban Ssonko\Training\10_2025_GEN_AI_TRAINING\generative_ai_lab\.venv\Lib\site-packages\fastmcp\utilities\logging.py:74, in configure_logging(level, logger, enable_rich_tracebacks, **rich_kwargs)
#      68 handler.addFilter(lambda record: record.exc_info is None)
#      70 # Configure the handler for tracebacks, for tracebacks we use a compressed format:
#      71 # no path or level name to maximize width available for the traceback
#      72 # suppress framework frames and limit the number of frames to 3
# ---> 74 import mcp
#      75 import pydantic
#      77 # Build traceback kwargs with defaults that can be overridden
#
# File c:\Users\Alban Ssonko\Training\10_2025_GEN_AI_TRAINING\generative_ai_lab\.venv\Lib\site-packages\mcp\__init__.py:2
#       1 from .client.session import ClientSession
# ----> 2 from .client.session_group import ClientSessionGroup
#       3 from .client.stdio import StdioServerParameters, stdio_client
#       4 from .server.session import ServerSession
#
# File c:\Users\Alban Ssonko\Training\10_2025_GEN_AI_TRAINING\generative_ai_lab\.venv\Lib\site-packages\mcp\client\session_group.py:28
#      26 from mcp.client.session import ElicitationFnT, ListRootsFnT, LoggingFnT, MessageHandlerFnT, SamplingFnT
#      27 from mcp.client.sse import sse_client
# ---> 28 from mcp.client.stdio import StdioServerParameters
#      29 from mcp.client.streamable_http import streamable_http_client
#      30 from mcp.shared._httpx_utils import create_mcp_http_client
#
# File c:\Users\Alban Ssonko\Training\10_2025_GEN_AI_TRAINING\generative_ai_lab\.venv\Lib\site-packages\mcp\client\stdio\__init__.py:17
#      15 import mcp.types as types
#      16 from mcp.os.posix.utilities import terminate_posix_process_tree
# ---> 17 from mcp.os.win32.utilities import (
#      18     FallbackProcess,
#      19     create_windows_process,
#      20     get_windows_executable_command,
#      21     terminate_windows_process_tree,
#      22 )
#      23 from mcp.shared.message import SessionMessage
#      25 logger = logging.getLogger(__name__)
#
# File c:\Users\Alban Ssonko\Training\10_2025_GEN_AI_TRAINING\generative_ai_lab\.venv\Lib\site-packages\mcp\os\win32\utilities.py:22
#      20 # Windows-specific imports for Job Objects
#      21 if sys.platform == "win32":
# ---> 22     import pywintypes
#      23     import win32api
#      24     import win32con
#
# ModuleNotFoundError: No module named 'pywintypes'

# %%
def decide_tool(text: str):
    text = text.lower()
    if "summarize" in text or "overview" in text:
        return "summarize", {}
    if "west" in text:
        return "query", {"expr": "region == 'West' and sales > 1500"}
    return "summarize", {}

async def run_agent(user_input, client):
    tool, params = decide_tool(user_input) #"summarize", {}
    #tool = "summarize"
    #params = {}
    print(f"Agent decided to use '{tool}'")

    # API for fastmcp 2.12.5
    result = await client.call_tool(tool, params)
    # result = await client.call_tool("query", params)

    print("Result:", result, "\n")

# %%
# create a connection to your MCP server
transport = PythonStdioTransport("mcp_server_fastmcp.py")

async with Client(transport) as client:
    await run_agent("Give me a summary of the dataset", client)

# %%
# create a connection to your MCP server
transport = PythonStdioTransport("mcp_server_fastmcp.py")

async with Client(transport) as client:
    await run_agent("Give me a summary of the dataset", client)
    await run_agent("Show West region sales > 1500", client)
